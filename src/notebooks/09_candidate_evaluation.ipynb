# %%
# evaluator = CandidateEvaluator()

# matched = evaluator.extract_candidates(
#     grover_outputs
# )

# for candidate in matched:
#     print(candidate.pattern.binary_window)
#     print(candidate.pattern.occurrences)
#     print(candidate.pattern.interaction_values)
#     print(candidate.probability)
#     print()
